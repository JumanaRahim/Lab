# %% [markdown]
# <a href="https://colab.research.google.com/github/JumanaRahim/Lab/blob/main/EXP.NO.4/LDA_IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file=pd.read_csv("/content/Iris.csv")
x=file[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]
y=file['Species']

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()

# %%
lda=lda.fit_transform(x,y)
lda
# Out:
# array([[ 8.0849532 ,  0.32845422],
#        [ 7.1471629 , -0.75547326],
#        [ 7.51137789, -0.23807832],
#        [ 6.83767561, -0.64288476],
#        [ 8.15781367,  0.54063935],
#        [ 7.72363087,  1.48232345],
#        [ 7.23514662,  0.3771537 ],
#        [ 7.62974497,  0.01667246],
#        [ 6.58274132, -0.98737424],
#        [ 7.36884116, -0.91362729],
#        [ 8.42181434,  0.67622968],
#        [ 7.24739721, -0.08292417],
#        [ 7.35062105, -1.0393597 ],
#        [ 7.59646896, -0.77671553],
#        [ 9.86936588,  1.61486093],
#        [ 9.18033614,  2.75558626],
#        [ 8.59760709,  1.85442217],
#        [ 7.7995682 ,  0.60905468],
#        [ 8.1000091 ,  0.99610981],
#        [ 8.04543611,  1.16244332],
#        [ 7.52046427, -0.156233  ],
#        [ 7.60526378,  1.22757267],
#        [ 8.70408249,  0.89959416],
#        [ 6.26374139,  0.46023935],
#        [ 6.59191505, -0.36199821],
#        [ 6.79210164, -0.93823664],
#        [ 6.84048091,  0.4848487 ],
# ...

# %%
new_df=pd.DataFrame(lda,columns=['LDA Comp1','LDA Comp2'])
new_df
# Out:
#      LDA Comp1  LDA Comp2
# 0     8.084953   0.328454
# 1     7.147163  -0.755473
# 2     7.511378  -0.238078
# 3     6.837676  -0.642885
# 4     8.157814   0.540639
# ..         ...        ...
# 145  -5.674013   1.661346
# 146  -5.197129  -0.365506
# 147  -4.981712   0.812973
# 148  -5.901486   2.320751
# 149  -4.684009   0.325081
#
# [150 rows x 2 columns]

# %%
Xaxis=new_df['LDA Comp1']
Yaxis=new_df['LDA Comp2']

# %%
import matplotlib.pyplot as plt
plt.scatter(Xaxis,Yaxis)
plt.xlabel('LDA Comp1')
plt.ylabel('LDA Comp2')
plt.show()
