# %% [markdown]
# <a href="https://colab.research.google.com/github/JumanaRahim/Lab/blob/main/TSAACFandPACF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
series=pd.read_csv("/content/daily-min-temperatures.csv",index_col='Date')
series
from matplotlib import pyplot
series.plot(figsize=(15,10))
pyplot.title("daily temperature")
pyplot.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(series,lags=50)
pyplot.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(series,lags=50)
pyplot.show()

# %%
series2=pd.read_csv("/content/daily-total-female-births.csv",index_col='Date')
series2
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %%
from matplotlib import pyplot
series2.plot(figsize=(15,10))
pyplot.title("female birth")
pyplot.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(series2,lags=50)
pyplot.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(series2,lags=50)
pyplot.show()

# %%
series2.hist()
pyplot.show()

# %%
x=series2.values
split=round(len(x)/2)
x1,x2=x[0:split],x[split:]
mean1,mean2=x1.mean(),x2.mean()
var1,var2=x1.var(),x2.var()
print(mean1,mean2)
# Out:
# 39.76373626373626 44.185792349726775

# %%
print(var1,var2)
# Out:
# 49.21341021615746 48.708650601690096

# %%
series3=pd.read_csv("/content/airline-passengers.csv",index_col='Month')
series3
# Out:
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121
# ...             ...
# 1960-08         606
# 1960-09         508
# 1960-10         461
# 1960-11         390
# 1960-12         432
#
# [144 rows x 1 columns]

# %%
series3.hist()
pyplot.show()

# %%
x=series3.values
split=round(len(x)/2)
x1,x2=x[0:split],x[split:]
mean1,mean2=x1.mean(),x2.mean()
var1,var2=x1.var(),x2.var()
print(mean1,mean2)
# Out:
# 182.90277777777777 377.69444444444446

# %%
print(var1,var2)
# Out:
# 2244.0877700617284 7367.962191358024

# %%
from numpy import log
x=series3.values
x=log(x)
pyplot.hist(x)
pyplot.show()
pyplot.plot(x)
pyplot.show()

# %%
x=series3.values
x=log(x)
split=round(len(x)/2)
x1,x2=x[0:split],x[split:]
mean1,mean2=x1.mean(),x2.mean()
var1,var2=x1.var(),x2.var()
print(mean1,mean2)
# Out:
# 5.17514614000377 5.909205777059973

# %%
print(var1,var2)
# Out:
# 0.06837486074542806 0.04926419375638024

# %%
from statsmodels.tsa.stattools import adfuller

# %%
series2=pd.read_csv("/content/daily-total-female-births.csv",index_col='Date',squeeze=True)
series2
x=series2.values
result=adfuller(x)
print(result)
# Out:
# (-4.808291253559765, 5.2434129901498554e-05, 6, 358, {'1%': -3.448748905151901, '5%': -2.8696473721448728, '10%': -2.5710891239349585}, 2343.8290926464197)

# %%
series3=pd.read_csv("/content/airline-passengers.csv",index_col='Month',squeeze=True)
series3
x=series3.values
result=adfuller(x)
print(result)
# Out:
# (0.8153688792060472, 0.991880243437641, 13, 130, {'1%': -3.4816817173418295, '5%': -2.8840418343195267, '10%': -2.578770059171598}, 996.6929308390189)

# %%
from logging import critical
print('ADF Static: %f' %result[0])
print('p-value: %f' %result[1])
# Out:
# ADF Static: -4.808291
# p-value: 0.000052
